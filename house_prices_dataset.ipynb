# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:\\Lokesh_workspace\\ML\\Regression_dataset\\house_prices_dataset.csv")
df.head()
# Out:
#    square_feet  num_rooms  age  distance_to_city(km)          price
# 0  2248.357077          3   92             22.997972  200374.090410
# 1  1930.867849          2   22             13.984254  268784.847337
# 2  2323.844269          6   33             21.500945  315020.857676
# 3  2761.514928          3   63             10.343638  355111.468459
# 4  1882.923313          7   54             25.485200  234197.123903

# %%
x=df.iloc[:,0:4].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
LinearRegression1=LinearRegression()
LinearRegression1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LinearRegression1.predict(x_test)

# %%
from sklearn.metrics import r2_score,root_mean_squared_error
r2_score(y_pred,y_test)
# Out:
# 0.9566617372673001

# %%
root_mean_squared_error(y_pred,y_test)
# Out:
# 19923.630822134794

# %%
print("coef: ",LinearRegression1.coef_)
print("Intercept: ",LinearRegression1.intercept_)
# Out:
# coef:  [  149.55463774 20030.75535312 -1003.96606947 -5016.56710821]
# Intercept:  863.4739036090323

# %%
heatmap_cmap = sns.light_palette("#0a3d62", as_cmap=True)

sns.heatmap(df.corr(numeric_only=True),annot=True,cmap=heatmap_cmap)
plt.title('Correlation Heatmap')
plt.show()
